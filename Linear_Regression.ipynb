# %% [markdown]
# <a href="https://colab.research.google.com/github/Johannmbo/Machine_learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_training.csv')
df
# Out:
#    Area    price
# 0   100  2500000
# 1   200  1440000
# 2   500  1350000
# 3   290  2900000
# 4   150  1500000
# 5   127  6000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    6 non-null      int64
#  1   price   6 non-null      int64
# dtypes: int64(2)
# memory usage: 228.0 bytes

# %%
df.shape
# Out:
# (6, 2)

# %%
df.describe().T
# Out:
#        count          mean           std        min         25%        50%  \
# Area     6.0  2.278333e+02  1.491850e+02      100.0      132.75      175.0
# price    6.0  2.615000e+06  1.776330e+06  1350000.0  1455000.00  2000000.0
#
#              75%        max
# Area       267.5      500.0
# price  2800000.0  6000000.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (12, 8))
plt.scatter(df['Area'], df['price'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (12, 8))
plt.scatter(df['Area'], df['price'], c='red', marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Linear_Regression')
plt.show()

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
y= df['price']
X =df.drop(columns=['price'])

# %%
y
# Out:
# 0    2500000
# 1    1440000
# 2    1350000
# 3    2900000
# 4    1500000
# 5    6000000
# Name: price, dtype: int64

# %%
X
# Out:
#    Area
# 0   100
# 1   200
# 2   500
# 3   290
# 4   150
# 5   127

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
price = model.predict([[225]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_model = model.predict(X)

# %%
print(price)
# Out:
# [2628588.72072909]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (15, 10))
plt.scatter(df['Area'], df['price'], c='red', marker='+')
plt.plot(X, predicted_model, c='blue')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Linear_Regression')
plt.show()

# %%
from sklearn import metrics
import seaborn as sns

# %%
metrics.r2_score(y, predicted_model)
# Out:
# 0.1622425001059904

# %%
sns.distplot(df['Area'])
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.title('Distribution of Area')
# Out:
# /tmp/ipython-input-1638171790.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Area'])
# Text(0.5, 1.0, 'Distribution of Area')

# %%
sns.jointplot(x='Area', y='price', data=df, kind='kde')
